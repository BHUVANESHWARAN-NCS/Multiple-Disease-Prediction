# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import plotly.express as px
import plotly.graph_objects as go

# %%
#kidney
df_kidney = pd.read_csv(r"D:\Data science\Projects\Multiple Disease Prediction\New\kidney_disease.csv")
df_kidney
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
df_kidney.head()
# Out:
#    id   age    bp     sg   al   su     rbc        pc         pcc          ba  \
# 0   0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent  notpresent
# 1   1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent  notpresent
# 2   2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent  notpresent
# 3   3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present  notpresent
# 4   4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent  notpresent
#
#    ...  pcv    wc   rc  htn   dm  cad appet   pe  ane classification
# 0  ...   44  7800  5.2  yes  yes   no  good   no   no            ckd
# 1  ...   38  6000  NaN   no   no   no  good   no   no            ckd
# 2  ...   31  7500  NaN   no  yes   no  poor   no  yes            ckd
# 3  ...   32  6700  3.9  yes   no   no  poor  yes  yes            ckd
# 4  ...   35  7300  4.6   no   no   no  good   no   no            ckd
#
# [5 rows x 26 columns]

# %%
df_kidney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
import numpy as np
column = ["wc","rc","pcv"]
for i in df_kidney.columns:
  if i in column:
    df_kidney[i]=df_kidney[i].replace('?',np.nan).astype(float)
    df_kidney[i]=df_kidney[i].fillna( df_kidney[i].mean())

# %%
df_kidney.describe()
# Out:
#                id         age          bp          sg          al          su  \
# count  400.000000  391.000000  388.000000  353.000000  354.000000  351.000000
# mean   199.500000   51.483376   76.469072    1.017408    1.016949    0.450142
# std    115.614301   17.169714   13.683637    0.005717    1.352679    1.099191
# min      0.000000    2.000000   50.000000    1.005000    0.000000    0.000000
# 25%     99.750000   42.000000   70.000000    1.010000    0.000000    0.000000
# 50%    199.500000   55.000000   80.000000    1.020000    0.000000    0.000000
# 75%    299.250000   64.500000   80.000000    1.020000    2.000000    0.000000
# max    399.000000   90.000000  180.000000    1.025000    5.000000    5.000000
#
#               bgr          bu          sc         sod         pot        hemo  \
# count  356.000000  381.000000  383.000000  313.000000  312.000000  348.000000
# mean   148.036517   57.425722    3.072454  137.528754    4.627244   12.526437
# ...

# %%
df_kidney.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                 0
# wc                  0
# rc                  0
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
df_kidney.fillna(method='bfill',inplace=True)
df_kidney.isnull().sum()
# Out:
# C:\Users\adminR\AppData\Local\Temp\ipykernel_14408\2340073378.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_kidney.fillna(method='bfill',inplace=True)
# id                0
# age               0
# bp                0
# sg                0
# al                0
# su                0
# rbc               0
# pc                0
# pcc               0
# ba                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
df_kidney.duplicated().sum()
# Out:
# 0

# %%
for i in df_kidney.select_dtypes(include="object").columns:
  print(i,df_kidney[i].unique())
# Out:
# rbc ['normal' 'abnormal']
# pc ['normal' 'abnormal']
# pcc ['notpresent' 'present']
# ba ['notpresent' 'present']
# htn ['yes' 'no']
# dm ['yes' 'no']
# cad ['no' 'yes']
# appet ['good' 'poor']
# pe ['no' 'yes']
# ane ['no' 'yes']
# classification ['ckd' 'notckd']

# %%
from sklearn.preprocessing import OrdinalEncoder
encode=OrdinalEncoder()

# %%
for i in df_kidney.select_dtypes(include="object").columns:
  df_kidney[i]=encode.fit_transform( df_kidney[[i]])

# %%
df_kidney.drop(['id'], axis=1, inplace=True)

# %%
df_kidney.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             400 non-null    float64
#  1   bp              400 non-null    float64
#  2   sg              400 non-null    float64
#  3   al              400 non-null    float64
#  4   su              400 non-null    float64
#  5   rbc             400 non-null    float64
#  6   pc              400 non-null    float64
#  7   pcc             400 non-null    float64
#  8   ba              400 non-null    float64
#  9   bgr             400 non-null    float64
#  10  bu              400 non-null    float64
#  11  sc              400 non-null    float64
#  12  sod             400 non-null    float64
#  13  pot             400 non-null    float64
#  14  hemo            400 non-null    float64
#  15  pcv             400 non-null    float64
#  16  wc              400 non-null    float64
# ...

# %%
df_kidney.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
x=df_kidney.drop(columns=['pcc', 'ba', 'bgr', 'bu','pot', 'hemo', 'pcv', 'htn', 'dm','pe', 'ane','classification'])
y=df_kidney["classification"]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
# Standardize numerical features
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x
# Out:
#       age    bp     sg   al   su  rbc   pc   sc    sod      wc        rc  cad  \
# 0    48.0  80.0  1.020  1.0  0.0  1.0  1.0  1.2  111.0  7800.0  5.200000  0.0
# 1     7.0  50.0  1.020  4.0  0.0  1.0  1.0  0.8  111.0  6000.0  4.707435  0.0
# 2    62.0  80.0  1.010  2.0  3.0  1.0  1.0  1.8  111.0  7500.0  4.707435  0.0
# 3    48.0  70.0  1.005  4.0  0.0  1.0  0.0  3.8  111.0  6700.0  3.900000  0.0
# 4    51.0  80.0  1.010  2.0  0.0  1.0  1.0  1.4  142.0  7300.0  4.600000  0.0
# ..    ...   ...    ...  ...  ...  ...  ...  ...    ...     ...       ...  ...
# 395  55.0  80.0  1.020  0.0  0.0  1.0  1.0  0.5  150.0  6700.0  4.900000  0.0
# 396  42.0  70.0  1.025  0.0  0.0  1.0  1.0  1.2  141.0  7800.0  6.200000  0.0
# 397  12.0  80.0  1.020  0.0  0.0  1.0  1.0  0.6  137.0  6600.0  5.400000  0.0
# 398  17.0  60.0  1.025  0.0  0.0  1.0  1.0  1.0  135.0  7200.0  5.900000  0.0
# 399  58.0  80.0  1.025  0.0  0.0  1.0  1.0  1.1  141.0  6800.0  6.100000  0.0
#
#      appet
# 0      0.0
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (360, 13)
# (40, 13)
# (360,)
# (40,)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
from sklearn.ensemble import RandomForestClassifier
model1 = RandomForestClassifier().fit(x_train,y_train)
y_pred=model1.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        24
#          1.0       1.00      1.00      1.00        16
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        24
#          1.0       1.00      1.00      1.00        16
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %%
from sklearn.ensemble import AdaBoostClassifier
model3 = AdaBoostClassifier().fit(x_train,y_train)
y_pred=model3.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        24
#          1.0       1.00      1.00      1.00        16
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
# C:\Users\adminR\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
from xgboost import XGBClassifier
model4 = XGBClassifier().fit(x_train,y_train)
y_pred=model4.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        24
#          1.0       1.00      1.00      1.00        16
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %%
from sklearn.svm import SVC
model5 = SVC().fit(x_train,y_train)
y_pred=model5.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.60      1.00      0.75        24
#          1.0       0.00      0.00      0.00        16
#
#     accuracy                           0.60        40
#    macro avg       0.30      0.50      0.38        40
# weighted avg       0.36      0.60      0.45        40
# C:\Users\adminR\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\adminR\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.linear_model import LogisticRegression
model6 = LogisticRegression().fit(x_train,y_train)
y_pred=model6.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        24
#          1.0       1.00      1.00      1.00        16
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40
# C:\Users\adminR\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import pickle
kidney_model = model6

# %%
with open("kidney_disease_model.pkl", "wb") as f:
    pickle.dump(kidney_model, f)

print("✅ kidney_disease_model.pkl saved successfully.")
# Out:
# ✅ kidney_disease_model.pkl saved successfully.

# %%
# Parkinson's
df_parkinsons = pd.read_csv(r"D:\Data science\Projects\Multiple Disease Prediction\New\parkinsons_disease.csv")
df_parkinsons
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
df_parkinsons.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df_parkinsons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df_parkinsons.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df_parkinsons.drop(['name'],axis=1,inplace=True)

# %%
df_parkinsons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   MDVP:Fo(Hz)       195 non-null    float64
#  1   MDVP:Fhi(Hz)      195 non-null    float64
#  2   MDVP:Flo(Hz)      195 non-null    float64
#  3   MDVP:Jitter(%)    195 non-null    float64
#  4   MDVP:Jitter(Abs)  195 non-null    float64
#  5   MDVP:RAP          195 non-null    float64
#  6   MDVP:PPQ          195 non-null    float64
#  7   Jitter:DDP        195 non-null    float64
#  8   MDVP:Shimmer      195 non-null    float64
#  9   MDVP:Shimmer(dB)  195 non-null    float64
#  10  Shimmer:APQ3      195 non-null    float64
#  11  Shimmer:APQ5      195 non-null    float64
#  12  MDVP:APQ          195 non-null    float64
#  13  Shimmer:DDA       195 non-null    float64
#  14  NHR               195 non-null    float64
#  15  HNR               195 non-null    float64
# ...

# %%
df_parkinsons.columns
# Out:
# Index(['MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)', 'MDVP:Jitter(%)',
#        'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP',
#        'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
#        'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'status', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
df_parkinsons.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
from sklearn.preprocessing import OrdinalEncoder
encode=OrdinalEncoder()

# %%
x=df_parkinsons.drop(columns=['MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ', 'Jitter:DDP','MDVP:Shimmer(dB)', 'Shimmer:APQ3', 'Shimmer:APQ5',
       'MDVP:APQ', 'Shimmer:DDA', 'NHR','status'])
y=df_parkinsons["status"]

# %%
x
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Shimmer  \
# 0        119.992       157.302        74.997         0.00784       0.04374
# 1        122.400       148.650       113.819         0.00968       0.06134
# 2        116.682       131.111       111.555         0.01050       0.05233
# 3        116.676       137.871       111.366         0.00997       0.05492
# 4        116.014       141.781       110.655         0.01284       0.06425
# ..           ...           ...           ...             ...           ...
# 190      174.188       230.978        94.261         0.00459       0.04087
# 191      209.516       253.017        89.488         0.00564       0.02751
# 192      174.688       240.005        74.287         0.01360       0.02308
# 193      198.764       396.961        74.904         0.00740       0.02296
# 194      214.289       260.277        77.973         0.00567       0.01884
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
# Standardize numerical features
scaler = StandardScaler()
xscaled = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (175, 12)
# (20, 12)
# (175,)
# (20,)

# %%
y_train.value_counts()
y_test.value_counts()
# Out:
# status
# 1    14
# 0     6
# Name: count, dtype: int64

# %%
from sklearn.metrics import accuracy_score,classification_report
from sklearn.ensemble import RandomForestClassifier
model1 = RandomForestClassifier().fit(x_train,y_train)
y_pred=model1.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.93      1.00      0.97        14
#
#     accuracy                           0.95        20
#    macro avg       0.97      0.92      0.94        20
# weighted avg       0.95      0.95      0.95        20

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.50      0.60         6
#            1       0.81      0.93      0.87        14
#
#     accuracy                           0.80        20
#    macro avg       0.78      0.71      0.73        20
# weighted avg       0.79      0.80      0.79        20

# %%
from sklearn.ensemble import AdaBoostClassifier
model3 = AdaBoostClassifier().fit(x_train,y_train)
y_pred=model3.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.87      0.93      0.90        14
#
#     accuracy                           0.85        20
#    macro avg       0.83      0.80      0.81        20
# weighted avg       0.85      0.85      0.85        20
# C:\Users\adminR\anaconda3\Lib\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(

# %%
from xgboost import XGBClassifier
model4 = XGBClassifier().fit(x_train,y_train)
y_pred=model4.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         6
#            1       0.82      1.00      0.90        14
#
#     accuracy                           0.85        20
#    macro avg       0.91      0.75      0.78        20
# weighted avg       0.88      0.85      0.83        20

# %%
from sklearn.svm import SVC
model5 = SVC().fit(x_train,y_train)
y_pred=model5.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         6
#            1       0.70      1.00      0.82        14
#
#     accuracy                           0.70        20
#    macro avg       0.35      0.50      0.41        20
# weighted avg       0.49      0.70      0.58        20
# C:\Users\adminR\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\adminR\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.linear_model import LogisticRegression
model6 = LogisticRegression().fit(x_train,y_train)
y_pred=model6.predict(x_test)
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         6
#            1       0.82      1.00      0.90        14
#
#     accuracy                           0.85        20
#    macro avg       0.91      0.75      0.78        20
# weighted avg       0.88      0.85      0.83        20
# C:\Users\adminR\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
import pickle
Parkinsons_model = model6

# %%
with open("Parkinsons_disease_model.pkl", "wb") as f:
    pickle.dump(Parkinsons_model, f)

print("✅ Parkinsons_disease_model.pkl saved successfully.")
# Out:
# ✅ Parkinsons_disease_model.pkl saved successfully.

# %%
# Liver 
df_liver = pd.read_csv(r"D:\Data science\Projects\Multiple Disease Prediction\New\liver_disease.csv")
df_liver

# %%
df_liver.head()

# %%
df_liver.info()

# %%
df_liver.describe()

# %%
df_liver.isnull().sum()

# %%
df_liver["Albumin_and_Globulin_Ratio"].mean()

# %%
df_liver.fillna(df_liver["Albumin_and_Globulin_Ratio"].mean(),inplace=True)

# %%
df_liver.duplicated().sum()

# %%
df_liver.drop_duplicates(keep="last",inplace=True)
df_liver.duplicated().sum()

# %%
df_liver.columns

# %%
from sklearn.preprocessing import OrdinalEncoder
encode=OrdinalEncoder()

# %%
df_liver["Gender"]=encode.fit_transform(df_liver[["Gender"]]) 
df_liver['Gender'] = df_liver['Gender'].astype(int)

# %%
df_liver.info()

# %%
pd.set_option("display.max_rows",None)
df_liver

# %%
# Separate features and target variable
x = df_liver.drop(columns=["Dataset","Gender"])
y = df_liver["Dataset"]

# %%
x

# %%
y

# %%
from sklearn.preprocessing import OrdinalEncoder
x1 = df_kidney.drop(columns='classification') 
encode=OrdinalEncoder()

# %%
x_scaled = encode.fit_transform(x1)

# %%
from sklearn.preprocessing import StandardScaler
# Standardize numerical features
scaler = StandardScaler()
xscaled = scaler.fit_transform(x)
x

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
from sklearn.ensemble import RandomForestClassifier
model1 = RandomForestClassifier().fit(x_train,y_train)
y_pred=model1.predict(x_test)
print(classification_report(y_test,y_pred))

# %%
from sklearn.tree import DecisionTreeClassifier
model2 = DecisionTreeClassifier().fit(x_train,y_train)
y_pred=model2.predict(x_test)
print(classification_report(y_test,y_pred))

# %%
import numpy as np
x_train = np.nan_to_num(x_train) 
x_test = np.nan_to_num(x_test)

# %%
from sklearn.ensemble import AdaBoostClassifier
model3 = AdaBoostClassifier().fit(x_train,y_train)
y_pred=model3.predict(x_test)
print(classification_report(y_test,y_pred))

# %%
from sklearn.ensemble import GradientBoostingClassifier
model4 = GradientBoostingClassifier().fit(x_train,y_train)
y_pred=model4.predict(x_test)
print(classification_report(y_test,y_pred))

# %%
from sklearn.svm import SVC
model5 = SVC().fit(x_train,y_train)
y_pred=model5.predict(x_test)
print(classification_report(y_test,y_pred))

# %%
y=np.where(y_train.values==1,0,1)
y

# %%
from xgboost import XGBClassifier
model6 = XGBClassifier().fit(x_train,y)
y_pred=model6.predict(x_test)
print(classification_report(y_test,y_pred))

# %%
from lazypredict.Supervised import LazyClassifier
clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)
models, predictions = clf.fit(x_train, x_test, y_train, y_test)
print(models)

# %%
from sklearn.ensemble import ExtraTreesClassifier
model7=ExtraTreesClassifier().fit(x_train,y_train)
y_pred=model7.predict(x_test)
print(classification_report(y_test,y_pred))

# %%
import pickle
pickle.dump(model_k, open("Liver_disease_model.pkl", "wb"))

# %%
import pickle
Liver_model = model6
with open("Li_disease_model.pkl", "wb") as file:
    pickle.dump(Liver_model, file)

print("✅ Kidney model saved as kidney_disease_model.pkl")
